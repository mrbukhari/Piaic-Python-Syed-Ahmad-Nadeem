# %%
# Implement the function file_to_list that receives a filename 
# and returns a list of words in that file
# Use str.split() (no arguments) to split on all whitespace.
# for opening and reading a file, look for a functions open(...) and read lines(...)

def file_to_lisht(filename):
    with open(filename,'r')as f:
        return str(f.readlines()).lower().split()
file_to_lisht('alice.txt')
# Out:
# ['["alice\'s',
#  'adventures',
#  'in',
#  'wonderland\\n",',
#  "'\\n',",
#  '"',
#  "alice's",
#  'adventures',
#  'in',
#  'wonderland\\n",',
#  "'\\n',",
#  "'",
#  'lewis',
#  "carroll\\n',",
#  "'\\n',",
#  "'",
#  'the',
#  'millennium',
#  'fulcrum',
#  'edition',
#  "3.0\\n',",
#  "'\\n',",
#  "'\\n',",
#  "'\\n',",
#  "'\\n',",
#  "'",
#  'chapter',
#  "i\\n',",
#  "'\\n',",
#  "'",
#  'down',
#  'the',
#  "rabbit-hole\\n',",
#  "'\\n',",
#  "'\\n',",
#  "'",
#  'alice',
#  'was',
#  'beginning',
#  'to',
#  'get',
#  'very',
#  'tired',
#  'of',
#  'sitting',
#  'by',
#  'her',
#  "sister\\n',",
#  "'on",
#  'the',
#  'bank,',
#  'and',
#  'of',
#  'having',
#  'nothing',
#  'to',
#  'do:',
#  'once',
#  'or',
#  'twice',
#  'she',
#  "had\\n',",
#  "'peeped",
#  'into',
#  'the',
#  'book',
#  'her',
#  'sister',
#  'was',
#  'reading,',
#  'but',
#  'it',
#  'had',
#  "no\\n',",
#  '"pictures',
#  'or',
#  'conversations',
#  'in',
#  'it,',
#  '`and',
#  'what',
# ...

# %%
# implement a print_words(filename) function that counts
# how often each word appears in the text and prints:
# word1 count1
# word2 count2
# ...
# Print the above list in order sorted by word (python will sort punctuation to
# come before letters -- that's fine). Store all the words as lowercase,
# so 'The' and 'the' count as the same word.
#i
def print_words(list_of_words):   
    dicti={}
    for i in list_of_words:
        dicti[i]=list_of_words.count(i) 
    return sorted(dicti.items(), key = lambda x: x[1], reverse = True)
    
print(print_words(file_to_lisht("alice.txt")))
# string22=input("Enter string : ")

# ##########################################3
# string2=input("Enter string : ")
# for i in string2:
#     print(i,string2.count(i), sep=",") 
# ##########################################
# ss = input().split()
# word = sorted(set(ss))     # split words are stored and sorted as a set
# #print(word)
# for i in word:
#     print("{0}:{1}".format(i,ss.count(i)))
# #############
# lis=[i for i, x in enumerate(bnr) if x == '1']
# Out:
# [('the', 1411), ("'\\n',", 874), ('and', 645), ('to', 629), ('"', 570), ('a', 545), ('she', 454), ('of', 440), ("'", 398), ('said', 397), ('it', 318), ('in', 316), ('was', 292), ('you', 238), ('i', 225), ('as', 224), ('alice', 198), ('that', 194), ('at', 187), ('her', 170), ('had', 155), ('with', 147), ('all', 140), ('on', 124), ('be', 115), ('for', 115), ('`i', 114), ('very', 113), ('so', 106), ('little', 102), ('but', 101), ('they', 99), ('not', 98), ('he', 94), ('out', 90), ('this', 89), ('his', 86), ('what', 81), ("the\\n',", 80), ('went', 71), ('about', 71), ('alice,', 71), ('if', 69), ('is', 68), ('were', 68), ('one', 68), ('would', 67), ('up', 66), ('down', 65), ('have', 63), ('could', 62), ('when', 61), ('there', 60), ('like', 59), ('into', 58), ('or', 55), ('thought', 55), ('your', 54), ('no', 53), ('by', 52), ('the\\n",', 52), ('`and', 51), ('*', 51), ('mock', 51), ('its', 50), ('an', 50), ('who', 50), ('quite', 48), ('then', 48), ('do', 48), ('my', 48), ("'the", 47), ('did
# ...

# %%
# implement a print_top(filename) which is similar
# to print_words() but which prints just the top 20 most common words sorted
# so the most common word is first, then the next most common, and so on.


def print_top(list_of_words):
    return list_of_words[:20]
print_top(print_words(file_to_lisht("alice.txt")))
# Out:
# [('the', 1411),
#  ("'\\n',", 874),
#  ('and', 645),
#  ('to', 629),
#  ('"', 570),
#  ('a', 545),
#  ('she', 454),
#  ('of', 440),
#  ("'", 398),
#  ('said', 397),
#  ('it', 318),
#  ('in', 316),
#  ('was', 292),
#  ('you', 238),
#  ('i', 225),
#  ('as', 224),
#  ('alice', 198),
#  ('that', 194),
#  ('at', 187),
#  ('her', 170)]

# %%
#len(dico.items())
# Out:
# 6521

# %%
from collections import Counter
woco= Counter(file_to_lisht("alice.txt"))
woco
# Out:
# Counter({'["alice\'s': 1,
#          'adventures': 4,
#          'in': 316,
#          'wonderland\\n",': 2,
#          "'\\n',": 874,
#          '"': 570,
#          "alice's": 11,
#          "'": 398,
#          'lewis': 1,
#          "carroll\\n',": 1,
#          'the': 1411,
#          'millennium': 1,
#          'fulcrum': 1,
#          'edition': 1,
#          "3.0\\n',": 1,
#          'chapter': 12,
#          "i\\n',": 10,
#          'down': 65,
#          "rabbit-hole\\n',": 1,
#          'alice': 198,
#          'was': 292,
#          'beginning': 7,
#          'to': 629,
#          'get': 39,
#          'very': 113,
#          'tired': 7,
#          'of': 440,
#          'sitting': 9,
#          'by': 52,
#          'her': 170,
#          "sister\\n',": 1,
#          "'on": 4,
#          'bank,': 2,
#          'and': 645,
#          'having': 7,
#          'nothing': 21,
#          'do:': 1,
#          'once': 17,
#          'or': 55,
#          'twice': 1,
# ...

# %%
woco.most_common(20)
# Out:
# [('the', 1411),
#  ("'\\n',", 874),
#  ('and', 645),
#  ('to', 629),
#  ('"', 570),
#  ('a', 545),
#  ('she', 454),
#  ('of', 440),
#  ("'", 398),
#  ('said', 397),
#  ('it', 318),
#  ('in', 316),
#  ('was', 292),
#  ('you', 238),
#  ('i', 225),
#  ('as', 224),
#  ('alice', 198),
#  ('that', 194),
#  ('at', 187),
#  ('her', 170)]
